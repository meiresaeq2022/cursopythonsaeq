# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/minicurso"
# Out:
# ls: cannot access '/content/drive/My Drive/minicurso': No such file or directory

# %%
import pandas as pd

# %% [markdown]
# PANDA AGR É PD

# %%
csv = pd.read_csv("/content/drive/My Drive/PYTHON/taxigov-corridas-7-dias.csv")

# %%
csv
# Out:
#         base_origem  qru_corrida                   nome_orgao  \
# 0        TAXIGOV_DF     629477.0     Presidência da República
# 1        TAXIGOV_DF     629480.0     Presidência da República
# 2        TAXIGOV_DF     629489.0     Presidência da República
# 3        TAXIGOV_DF     629491.0  Ministério das Comunicações
# 4        TAXIGOV_DF     629494.0     Presidência da República
# ...             ...          ...                          ...
# 3065  TAXIGOV_SP_10     252287.0                         ANTT
# 3066  TAXIGOV_SP_10     252764.0                         ANAC
# 3067  TAXIGOV_SP_10     252317.0          MINISTERIO DA SAUDE
# 3068  TAXIGOV_SP_10     252754.0                         ANTT
# 3069  TAXIGOV_SP_10     251817.0                         ANAC
#
#          status_corrida                                     motivo_corrida  \
# 0             CONCLUÍDA                                1 - REUNIAO EXTERNA
# 1             CONCLUÍDA                                1 - REUNIAO EXTERNA
# 2             CONCLUÍDA                                1 - REUNIAO EXTERNA
# 3             CONCLUÍDA                                1 - REUNIAO EXTERNA
# 4             CONCLUÍDA                                1 - REUNIAO EXTERNA
# ...                 ...                                                ...
# 3065  AGUARDANDO ATESTE                                    06 Fiscalização
# 3066  AGUARDANDO ATESTE                                    06 Fiscalização
# 3067  AGUARDANDO ATESTE  12 Visitas técnicas (a prestadores de serviço,...
# 3068          CANCELADA                                          04 Outros
# 3069          CONCLUÍDA                                    06 Fiscalização
#
#       km_total  valor_corrida            data_abertura  \
# 0       14.440          51.27  2022-08-16 01:56:15.690
# 1       17.900          63.56  2022-08-16 03:36:59.557
# 2       12.620          44.80  2022-08-16 05:07:22.370
# 3       57.700         204.85  2022-08-16 05:27:04.393
# 4       17.610          62.51  2022-08-16 05:49:25.160
# ...        ...            ...                      ...
# 3065     8.329          24.99  2022-08-18 08:12:57.663
# 3066    31.474          94.42  2022-08-19 17:15:07.940
# 3067     9.601          28.80  2022-08-18 09:35:57.250
# 3068       NaN            NaN  2022-08-19 16:44:16.940
# 3069    38.079         114.24  2022-08-16 15:20:36.330
#
#                 data_despacho      data_local_embarque  ...  \
# 0     2022-08-16 05:03:00.650  2022-08-16 05:19:00.720  ...
# 1     2022-08-16 03:37:12.270  2022-08-16 03:40:14.810  ...
# 2     2022-08-16 05:07:42.413  2022-08-16 05:27:55.043  ...
# 3     2022-08-16 05:27:15.043  2022-08-16 05:27:15.150  ...
# 4     2022-08-16 06:20:49.200  2022-08-16 06:27:13.137  ...
# ...                       ...                      ...  ...
# 3065  2022-08-18 08:12:57.663  2022-08-18 08:25:34.000  ...
# 3066  2022-08-19 17:15:07.940  2022-08-19 17:54:45.000  ...
# 3067  2022-08-18 09:35:57.250  2022-08-18 09:51:32.000  ...
# 3068  2022-08-19 17:00:00.000                      NaN  ...
# 3069  2022-08-16 17:15:00.000  2022-08-16 16:55:23.000  ...
#
#                             destino_solicitado_endereco  \
# 0           BABR - Base Aerea de Brasilia, Brasilia, DF
# 1     Residencial Paradise Club, QNC 1, AE. 21, Av. ...
# 2     BABR - Base Aerea de Brasilia, Brasilia, Distr...
# 3     BABR - Base Aerea de Brasilia, Brasilia, Distr...
# 4           BABR - Base Aerea de Brasilia, Brasilia, DF
# ...                                                 ...
# 3065  R. DEP. VICENTE PENIDO, 212 - VILA GUILHERME, ...
# 3066  AV. BARAO DO REGO BARROS, 664 - VILA CONGONHAS...
# 3067  RUA DOM RAIMUNDO BRITO, 104 - ACLIMACAO, SAO P...
# 3068                   Rua Deputado Vicente Penido, 255
# 3069  R. RENASCENCA, 801 - VILA CONGONHAS, SAO PAULO...
#
#                                destino_efetivo_endereco origem_latitude  \
# 0                        AEB - BRASILIA - DF - BRASILIA      -15.821636
# 1     QNC 1 - TAGUATINGA NORTE TAGUATINGA - 72115-51...      -15.792739
# 2                        AEB - BRASILIA - DF - BRASILIA      -15.797774
# 3                        AEB - BRASILIA - DF - LUZIANIA      -16.270131
# 4                        AEB - BRASILIA - DF - BRASILIA      -15.776235
# ...                                                 ...             ...
# 3065                        RUA DEPUTADO VICENTE PENIDO      -23.545197
# 3066                       AVENIDA BARAO DO REGO BARROS      -23.430573
# 3067                             RUA DOM RAIMUNDO BRITO      -23.495864
# 3068                                                NaN      -23.545241
# 3069                                     RUA RENASCENCA      -23.430573
#
#      origem_longitude destino_solicitado_latitude  \
# 0          -47.984223                  -15.871267
# 1          -47.913962                  -15.832194
# 2          -47.940375                  -15.871267
# 3          -47.914636                  -15.871267
# 4          -47.879189                  -15.871267
# ...               ...                         ...
# 3065       -46.638183                  -23.519461
# 3066       -46.473043                  -23.624886
# 3067       -46.622291                  -23.567772
# 3068       -46.638079                  -23.519285
# 3069       -46.473043                  -23.625229
#
#      destino_solicitado_longitude destino_efetivo_latitude  \
# 0                      -47.908699               -15.867617
# 1                      -48.061564               -15.831795
# 2                      -47.908699               -15.867665
# 3                      -47.908699               -15.869302
# 4                      -47.908699               -15.867851
# ...                           ...                      ...
# 3065                   -46.595715               -23.519500
# 3066                   -46.663971               -23.624900
# 3067                   -46.631853               -23.567800
# 3068                   -46.595720                      NaN
# 3069                   -46.662234               -23.625200
#
#      destino_efetivo_longitude     ateste_setorial_data  conteste_info
# 0                   -47.910456                      NaN            NaN
# 1                   -48.061732                      NaN            NaN
# 2                   -47.910427                      NaN            NaN
# 3                   -47.910821                      NaN            NaN
# 4                   -47.910378                      NaN            NaN
# ...                        ...                      ...            ...
# 3065                -46.595700                      NaN            NaN
# 3066                -46.664000                      NaN            NaN
# 3067                -46.631900                      NaN            NaN
# 3068                       NaN                      NaN            NaN
# 3069                -46.662200  2022-08-19 06:56:52.703            NaN
#
# [3070 rows x 26 columns]

# %%
csv['valor_corrida']
# Out:
# 0        51.27
# 1        63.56
# 2        44.80
# 3       204.85
# 4        62.51
#          ...
# 3065     24.99
# 3066     94.42
# 3067     28.80
# 3068       NaN
# 3069    114.24
# Name: valor_corrida, Length: 3070, dtype: float64

# %% [markdown]
# NaN é valor errado

# %%
valor_corrida = csv['valor_corrida'].dropna()
km_total = csv ['km_total'].dropna

# %%
print(f'Numero de linhas: {len(valor_corrida)}')
# Out:
# Numero de linhas: 2905

# %% [markdown]
# **contagem numero de linhas**

# %% [markdown]
# Usar len pra contar as linhas, mode: moda , media:mean, mediana median

# %%
print(f'moda:{ valor_corrida.mode()}')
# Out:
# moda:0    7.1
# dtype: float64

# %%
print(f'mediana: {valor_corrida.median()}')
# Out:
# mediana: 18.91

# %%
print((f'media: {valor_corrida.mean()}'))
# Out:
# media: 32.86953184165232

# %%
print((f'Amplitude: {valor_corrida.max()- valor_corrida.min()}'))
# Out:
# Amplitude: 765.36

# %%
print((f'Variância: {valor_corrida.var()}'))
# Out:
# Variância: 1586.4304878661517

# %%
print((f'Desvio: {valor_corrida.std()}'))
# Out:
# Desvio: 39.830019933037335

# %%
valor_corrida.hist()

# %%
valor_km = csv [['valor_corrida' ,'km_total']]

# %%
valor_km.plot()

# %%
valor_km = valor_km.dropna ()

# %%
corr = valor_km.corr()

# %%
corr
# Out:
#                valor_corrida  km_total
# valor_corrida       1.000000  0.994457
# km_total            0.994457  1.000000

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize = (9, 9))
ax.hist(km_total, bins=5, edgecolor= "black")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-1862b373096b> in <module>
#       1 fig, ax = plt.subplots(figsize = (9, 9))
# ----> 2 ax.hist(km_total, bins=5, edgecolor= "black")
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6628                     # python's min/max ignore nan,
#    6629                     # np.minnan returns nan for all nan input
# -> 6630                     xmin = min(xmin, np.nanmin(xi))
#    6631                     xmax = max(xmax, np.nanmax(xi))
#    6632             # make sure we have seen at least one non-nan and finite
#
# TypeError: '<' not supported between instances of 'method' and 'float'

# %%
import seaborn as sns
df = sns.load_dataset('iris')

sns.boxplot( x=df["species"], y=df["sepal_length"] )
