# %%
a = int(input('digite n1: '))
# Out:
# digite n110

# %%
b=int(input('digite n2: '))
# Out:
# digite n220

# %%
if a > b :
    print(a)


else :
  print (b)
# Out:
# 20

# %%
Num1=int(input('digite Num1: '))
# Out:
# digite Num1: 10

# %%
Num2=int(input('digite Num2: '))
# Out:
# digite Num2: 20

# %%
if Num1 > Num2:
  print(f"O maior deles é: {Num1}")
else:
  print(f"O maior deles é: {Num2}")
# Out:
# O maior deles é: 20

# %%
N = int(input('digite N: '))
# Out:
# digite N: 10

# %%
if N > 0:
  print("Positivo")
else:
  print ("Negativo")
# Out:
# Positivo

# %%
letra=input('digite a letra: ' )
# Out:
# digite a letra: m

# %%
if letra == 'F' or letra == 'f':
  print("Feminino")

elif letra == 'M' or letra == 'm':
  print("Masculino")
else:
  print("Nenhum")
# Out:
# Masculino

# %% [markdown]
# ex4

# %%
Letra2 = input('digite a letra2: ' )

if letra == 'a' or letra == 'e' or letra == 'i' or 'o' or 'u':
  print(vogal)
else:
  print(consoante)
# Out:
# digite a letra2: a
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-022cad549c91> in <module>
#       2
#       3 if (letra == 'a' or 'e' or 'i' or 'o' or 'u'):
# ----> 4   print(vogal)
#       5 else:
#       6   print(consoante)
#
# NameError: name 'vogal' is not defined

# %%
vetor = []
for i in range (0,5):
  cod=int(input(f"Digite o numero : "))
  vetor.appen(cod)
print(vetor)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-107-5804996cec59> in <module>
#       1 vetor = []
#       2 for i in range (0,5):
# ----> 3   cod=int(input(f"Digite o numero : "))
#       4   vetor.appen(cod)
#       5 print(vetor)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
# ...

# %% [markdown]
# *exemplo6, faça um programa que leia 3 numeros e mostre o menor*

# %%
C1=int(input('digite Num2: '))
# Out:
# digite Num2: 8

# %%
C2=int(input('digite Num2: '))
# Out:
# digite Num2: 2

# %%
C3=int(input('digite Num2: '))
# Out:
# digite Num2: 3

# %%
if C1 > C2 and C1 > C3:
  print(f"O maior é {C1}")
elif C2 > C1 and C2 > C3:
  print(f"O maior é {C2}")
else:
  print(f"O maior é {C3}")
# Out:
# O maior é 8

# %% [markdown]
# EX3

# %% [markdown]
# ex9_ leia 4 numeros mostre os numeros e a media

# %%
vetor = []
for i in range (0,4):
  notas=int(input("Digite as notas: "))
  vetor.append(notas)
print(f"notas: {vetor}")
# Out:
# Digite as notas: 1
# Digite as notas: 4
# Digite as notas: 45
# Digite as notas: 67658
# notas: [1, 4, 45, 67658]

# %%
a1 = int(input("Digite o número inicial dea PA: "))
razao = int(input("Digite a razao da PA: "))
termos = int(input("Digite o numero de termos da PA: "))
cout=1
while ( cout <= termos)
 n=a1+(cout-1)*razao
 print(f"Termo{cout}:{n}")
  cout+=1
# Out:
#   File "<ipython-input-1-6d22a0294ebe>", line 5
#     while ( cout <= termos)
#                            ^
# SyntaxError: invalid syntax
